# %%
import gym, os
from itertools import count, product
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
import numpy as np
import json
import matplotlib.pyplot as plt
import argparse
import warnings



device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

config_file = "/home/raghuram/Prateek_Codes/Final Off-Policy Experiments/MountainCar-Shaped/AC_TD0/train_config.json"

with open(config_file) as json_file:
    config = json.load(json_file)

def video_callable(episode_number):
    return episode_number%config['recording_frequency'] == 0

env = gym.make(config['env'])
ratio_estimation_env = gym.make(config['env'])

if config['record']:
    env = gym.wrappers.Monitor(env, config['recording_path'], force = True, video_callable=video_callable)

if config['episode_length'] is not None:
    env._max_episode_steps = config['episode_length']
    ratio_estimation_env._max_episode_steps = config['episode_length']

if config['numpy_seed'] is not None:
    np.random.seed(config['numpy_seed'])

if config['environment_seed'] is not None:
    env.seed(config['environment_seed'])
    ratio_estimation_env.seed(config['environment_seed'])

if config['pytorch_seed'] is not None:
    torch.manual_seed(config['pytorch_seed'])

state_size = env.observation_space.shape[0]
action_size = env.action_space.n
actor_h_layers_sizes = config['actor']['hidden_layer_neurons']
critic_h_layers_sizes = config['critic']['hidden_layer_neurons']
w_h_layers_sizes = config['w']['hidden_layer_neurons']
y_h_layers_sizes = config['y']['hidden_layer_neurons']
gamma = config['gamma']
lr_A = config['actor']['learning_rate']
lr_C = config['critic']['learning_rate']
lr_W = config['w']['learning_rate']
lr_Y = config['y']['learning_rate']
load_A = config['actor']['load']
load_C = config['critic']['load']
load_W = config['w']['load']
load_Y = config['y']['load']
random_behaviour = config['random_behaviour']
iterations = config['iterations']
estimation_samples = config['estimation_samples']

class Actor(nn.Module):
    def __init__(self, input_size, h_layers_sizes, output_size):
        super(Actor, self).__init__()
        self.input_size = input_size
        self.h_layers_sizes = h_layers_sizes
        self.all_layers_sizes = [input_size] + h_layers_sizes + [output_size]
        self.output_size = output_size
        self.linears = nn.ModuleList([nn.Linear(self.all_layers_sizes[i], self.all_layers_sizes[i+1], bias=False) for i in range(len(self.all_layers_sizes)-1)])

    def forward(self, state):
        output = torch.tanh(self.linears[0](state))
        for i in range(1,len(self.linears)-1):
            output = torch.tanh(self.linears[i](output))
        output = self.linears[-1](output)
        distribution = Categorical(F.softmax(output, dim=-1))
        return distribution


class Critic(nn.Module):
    def __init__(self, input_size, h_layers_sizes, output_size):
        super(Critic, self).__init__()
        self.input_size = input_size
        self.h_layers_sizes = h_layers_sizes
        self.all_layers_sizes = [input_size] + h_layers_sizes + [output_size]
        self.output_size = output_size
        self.linears = nn.ModuleList([nn.Linear(self.all_layers_sizes[i], self.all_layers_sizes[i+1]) for i in range(len(self.all_layers_sizes)-1)])

    def forward(self, state):
        value = F.relu(self.linears[0](state))
        for i in range(1,len(self.linears)-1):
            value = F.relu(self.linears[i](value))
        value = self.linears[-1](value)
        return value

class W(nn.Module):
    def __init__(self, input_size, h_layers_sizes, output_size):
        super(W, self).__init__()
        self.input_size = input_size
        self.h_layers_sizes = h_layers_sizes
        self.all_layers_sizes = [input_size] + h_layers_sizes + [output_size]
        self.output_size = output_size
        self.linears = nn.ModuleList([nn.Linear(self.all_layers_sizes[i], self.all_layers_sizes[i+1]) for i in range(len(self.all_layers_sizes)-1)])

    def forward(self, state):
        value = F.relu(self.linears[0](state))
        for i in range(1,len(self.linears)-1):
            value = F.relu(self.linears[i](value))
        value = torch.exp(self.linears[-1](value))
        return value

class Y(nn.Module):
    def __init__(self, input_size, h_layers_sizes, output_size):
        super(Y, self).__init__()
        self.input_size = input_size
        self.h_layers_sizes = h_layers_sizes
        self.all_layers_sizes = [input_size] + h_layers_sizes + [output_size]
        self.output_size = output_size
        self.linears = nn.ModuleList([nn.Linear(self.all_layers_sizes[i], self.all_layers_sizes[i+1]) for i in range(len(self.all_layers_sizes)-1)])

    def forward(self, state):
        value = F.relu(self.linears[0](state))
        for i in range(1,len(self.linears)-1):
            value = F.relu(self.linears[i](value))
        value = torch.exp(self.linears[-1](value))
        return value

def kernel(state1, state2, l = 1):
    d = torch.norm(state1 - state2)
    return torch.exp(-((d**2)/(2*(l**2))))

def estimate_W(target_policy, w, optimizerW, random_behaviour = True, behaviour_policy = None, iterations = 5000, samples = 1000):

    for iter in range(iterations):
        w_state1_list = []
        w_state2_list = []
        w_next_state1_list = []
        w_next_state2_list = []
        beta1_list = []
        beta2_list = []
        kernel_value_list = []
        z_w_state = 0

        training_data = []
        initial_state = ratio_estimation_env.reset()
        initial_state = torch.FloatTensor(initial_state).to(device)
        state = initial_state

        for i in range(samples):
            
            if random_behaviour == False:
                dist_behaviour = behaviour_policy(state)
                action = dist_behaviour.sample()
            else:
                action = torch.randint(0, action_size, (1,)).to(device)
                action = torch.squeeze(action)

            next_state, reward, done, _ = ratio_estimation_env.step(action.cpu().numpy())

            next_state = torch.FloatTensor(next_state).to(device)

            dist_target = target_policy(state)

            if random_behaviour == False:
                beta = (dist_target.probs[action]/dist_behaviour.probs[action]).detach()
            else:
                beta = dist_target.probs[action].detach()*action_size
            
            training_data.append([state,beta,next_state])

            state = next_state

            if done:
                break

        batch = [[None, None, initial_state]]

        for i in range(len(training_data)):
            d = np.random.uniform()
            if d < gamma**(i+1):
                batch.append(training_data[i])

        pairs = list(product(batch, repeat=2))

        for pair in pairs:
            sample1 = pair[0]
            sample2 = pair[1]

            if sample1[0] != None:
                w_state1 = w(sample1[0])
            else:
                w_state1 = None

            if sample2[0] != None:
                w_state2 = w(sample2[0])
            else:
                w_state2 = None

            beta1 = sample1[1]
            beta2 = sample2[1]

            w_next_state1 = w(sample1[2])
            w_next_state2 = w(sample2[2])

            kernel_value = kernel(sample1[2], sample2[2])

            w_state1_list.append(w_state1)
            w_state2_list.append(w_state2)
            w_next_state1_list.append(w_next_state1)
            w_next_state2_list.append(w_next_state2)
            beta1_list.append(beta1)
            beta2_list.append(beta2)
            kernel_value_list.append(kernel_value)

        for sample in batch[1:]:
            w_state = w(sample[0])
            z_w_state += w_state

        z_w_state /= len(batch)

        w_loss = 0

        for i in range(len(pairs)):
            if w_state1_list[i] == None and w_state2_list[i] == None:
                w_loss += (1 - (w_next_state1_list[i]/z_w_state))*(1 - (w_next_state2_list[i]/z_w_state))*kernel_value_list[i]

            elif w_state1_list[i] == None:
                w_loss += (1 - (w_next_state1_list[i]/z_w_state))*(beta2_list[i]*(w_state2_list[i]/z_w_state) - (w_next_state2_list[i]/z_w_state))*kernel_value_list[i]

            elif w_state2_list[i] == None:
                w_loss += (beta1_list[i]*(w_state1_list[i]/z_w_state) - (w_next_state1_list[i]/z_w_state))*(1 - (w_next_state2_list[i]/z_w_state))*kernel_value_list[i]

            else:
                w_loss += (beta1_list[i]*(w_state1_list[i]/z_w_state) - (w_next_state1_list[i]/z_w_state))*(beta2_list[i]*(w_state2_list[i]/z_w_state) - (w_next_state2_list[i]/z_w_state))*kernel_value_list[i]

        w_loss /= len(batch)
        optimizerW.zero_grad()
        w_loss.backward()
        optimizerW.step()
        optimizerW.zero_grad()

def estimate_Y(target_policy, y, optimizerY, random_behaviour = True, behaviour_policy = None, iterations = 5000, samples = 1000):

    for iter in range(iterations):
        y_state1_list = []
        y_state2_list = []
        y_next_state1_list = []
        y_next_state2_list = []
        beta1_list = []
        beta2_list = []
        kernel_value_list = []
        z_y_state = 0

        training_data = []
        state = ratio_estimation_env.reset()
        state = torch.FloatTensor(state).to(device)

        for i in range(samples):
            
            if random_behaviour == False:
                dist_behaviour = behaviour_policy(state)
                action = dist_behaviour.sample()
            else:
                action = torch.randint(0, action_size, (1,)).to(device)
                action = torch.squeeze(action)

            next_state, reward, done, _ = ratio_estimation_env.step(action.cpu().numpy())

            next_state = torch.FloatTensor(next_state).to(device)

            dist_target = target_policy(state)

            if random_behaviour == False:
                beta = (dist_target.probs[action]/dist_behaviour.probs[action]).detach()
            else:
                beta = dist_target.probs[action].detach()*action_size
            
            training_data.append([state,beta,next_state])

            state = next_state

            if done:
                break

        pairs = list(product(training_data, repeat=2))

        for pair in pairs:
            sample1 = pair[0]
            sample2 = pair[1]

            y_state1 = y(sample1[0])
            y_state2 = y(sample2[0])

            beta1 = sample1[1]
            beta2 = sample2[1]

            y_next_state1 = y(sample1[2])
            y_next_state2 = y(sample2[2])

            kernel_value = kernel(sample1[2], sample2[2])

            y_state1_list.append(y_state1)
            y_state2_list.append(y_state2)
            y_next_state1_list.append(y_next_state1)
            y_next_state2_list.append(y_next_state2)
            beta1_list.append(beta1)
            beta2_list.append(beta2)
            kernel_value_list.append(kernel_value)

        for sample in training_data:
            y_state = y(sample[0])
            z_y_state += y_state

        z_y_state /= len(training_data)

        y_loss = 0

        for i in range(len(pairs)):
            y_loss += (beta1_list[i]*(y_state1_list[i]/z_y_state) - (y_next_state1_list[i]/z_y_state))*(beta2_list[i]*(y_state2_list[i]/z_y_state) - (y_next_state2_list[i]/z_y_state))*kernel_value_list[i]

        y_loss /= len(training_data)
        optimizerY.zero_grad()
        y_loss.backward()
        optimizerY.step()
        optimizerY.zero_grad()

def lr_scheduler(optimizerA, optimizerC, total_reward):
    for schedule in config['learning_rate_scheduler']['schedule']:
        if total_reward >= schedule[0][0] and total_reward < schedule[0][1]:
            optimizerA.param_groups[0]['lr'] = schedule[1]['lr_A']
            optimizerC.param_groups[0]['lr'] = schedule[1]['lr_C']

def evaluate_policy(actor):
    state = env.reset()
    state = torch.FloatTensor(state).to(device)
    total_reward = 0

    for i in count():
        if config['render']:
            env.render()

        dist = actor(state)
        action = dist.sample()

        next_state, reward, done, _ = env.step(action.cpu().numpy())
        total_reward += reward

        next_state = torch.FloatTensor(next_state).to(device)
        state = next_state

        if done:
            break

    return total_reward

def trainIters(actor, critic, w, y, random_behaviour = True, behaviour_policy = None, n_iters = 5000):
    optimizerA = optim.Adam(actor.parameters(), lr=lr_A)
    optimizerC = optim.Adam(critic.parameters(), lr=lr_C)
    optimizerW = optim.Adam(w.parameters(), lr=lr_W)
    optimizerY = optim.Adam(y.parameters(), lr=lr_Y)
    running_total_reward = 0
    max_running_total_reward = -float('inf')
    reward_list = []

    for iter in range(n_iters):
        state = env.reset()
        state = torch.FloatTensor(state).to(device)
        estimate_W(actor, w, optimizerW, random_behaviour, behaviour_policy, iterations = 1, samples = estimation_samples)
        estimate_Y(actor, y, optimizerY, random_behaviour, behaviour_policy, iterations = 1, samples = estimation_samples)

        for i in count():
            if config['render']:
                env.render()
            
            if random_behaviour == False:
                dist_behaviour = behaviour_policy(state)
                action = dist_behaviour.sample()
            else:
                action = torch.randint(0, action_size, (1,)).to(device)
                action = torch.squeeze(action)

            dist_target = actor(state)

            next_state, reward, done, _ = env.step(action.cpu().numpy())
            
            if next_state[0] > 0.1 and next_state[0] < 0.4:
                reward += 10
            elif next_state[0] >= 0.4 and next_state[0] < 0.6:
                reward += 20
            if done == True and i < config['episode_length']-1:
                reward += 1000

            if random_behaviour == False:
                beta = (dist_target.probs[action]/dist_behaviour.probs[action]).detach()
            else:
                beta = dist_target.probs[action].detach()*action_size

            log_prob = dist_target.log_prob(action).unsqueeze(0)
            
            value = critic(state)

            next_state = torch.FloatTensor(next_state).to(device)
            next_value = critic(next_state)

            if done:                
                error = reward - value
                critic_loss = error.pow(2)
                optimizerC.zero_grad()
                critic_loss.backward()
                y_ratio = y(state).detach()
                for j in range(len(critic.all_layers_sizes)-1):
                    critic.linears[j].weight.grad = y_ratio*beta*critic.linears[j].weight.grad
                optimizerC.step()
                optimizerC.zero_grad()

                value = critic(state)
                next_value = critic(next_state)
                advantage = reward - value
                actor_loss = -log_prob * advantage.detach()
                optimizerA.zero_grad()
                actor_loss.backward()
                w_ratio = w(state).detach()
                for j in range(len(actor.all_layers_sizes)-1):
                    actor.linears[j].weight.grad = w_ratio*beta*actor.linears[j].weight.grad
                optimizerA.step()
                optimizerA.zero_grad()

                total_reward = evaluate_policy(actor)

                running_total_reward = total_reward if running_total_reward == 0 else running_total_reward * 0.9 + total_reward * 0.1
                print('Iteration: {}, Current Total Reward: {}, Running Total Reward: {}'.format(iter, total_reward, round(running_total_reward,2)))

                reward_list.append(running_total_reward)

                if max_running_total_reward <= running_total_reward:
                    torch.save(actor, config['actor']['final_save_path'])
                    torch.save(critic, config['critic']['final_save_path'])
                    max_running_total_reward = running_total_reward

                if config['learning_rate_scheduler']['required']:
                    lr_scheduler(optimizerA, optimizerC, max_running_total_reward)

                break
            else:
                error = reward + gamma * next_value.detach() - value
                critic_loss = error.pow(2)
                optimizerC.zero_grad()
                critic_loss.backward()
                y_ratio = y(state).detach()
                for j in range(len(critic.all_layers_sizes)-1):
                    critic.linears[j].weight.grad = y_ratio*beta*critic.linears[j].weight.grad
                optimizerC.step()
                optimizerC.zero_grad()

                value = critic(state)
                next_value = critic(next_state)
                advantage = reward + gamma * next_value.detach() - value
                actor_loss = -log_prob * advantage.detach()
                optimizerA.zero_grad()
                actor_loss.backward()
                w_ratio = w(state).detach()
                for j in range(len(actor.all_layers_sizes)-1):
                    actor.linears[j].weight.grad = w_ratio*beta*actor.linears[j].weight.grad
                optimizerA.step()
                optimizerA.zero_grad()

                state = next_state

    env.close()
    ratio_estimation_env.close()
    with open(config['rewards_path'], 'w') as fp:
        json.dump(reward_list, fp, indent=4)


if __name__ == '__main__':
    if load_A:
        path_A = config['actor']['load_path']
        actor = torch.load(path_A).to(device)
        print('Actor Model loaded')
    else:
        actor = Actor(state_size, actor_h_layers_sizes, action_size).to(device)
        torch.save(actor, config['actor']['initial_save_path'])
    
    if load_C:
        path_C = config['critic']['load_path']
        critic = torch.load(path_C).to(device)
        print('Critic Model loaded')
    else:    
        critic = Critic(state_size, critic_h_layers_sizes, 1).to(device)
        torch.save(critic, config['critic']['initial_save_path'])

    if load_W:
        path_W = config['w']['load_path']
        w = torch.load(path_W).to(device)
        print('W Model loaded')
    else:    
        w = W(state_size, w_h_layers_sizes, 1).to(device)
        torch.save(w, config['w']['initial_save_path'])

    if load_Y:
        path_Y = config['y']['load_path']
        y = torch.load(path_Y).to(device)
        print('Y Model loaded')
    else:    
        y = Y(state_size, y_h_layers_sizes, 1).to(device)
        torch.save(y, config['y']['initial_save_path'])

    if random_behaviour:
        behaviour_policy = None
    else:
        behaviour_policy = torch.load(config['behaviour_policy_path']).to(device)
        print('Behaviour Policy loaded')

    trainIters(actor, critic, w, y, random_behaviour, behaviour_policy, n_iters=iterations)
# Out:
# /home/raghuram/anaconda3/lib/python3.6/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# Iteration: 0, Current Total Reward: -10000.0, Running Total Reward: -10000.0
# Iteration: 1, Current Total Reward: -10000.0, Running Total Reward: -10000.0
# Iteration: 2, Current Total Reward: -10000.0, Running Total Reward: -10000.0
# Iteration: 3, Current Total Reward: -10000.0, Running Total Reward: -10000.0
# Iteration: 4, Current Total Reward: -4343.0, Running Total Reward: -9434.3
# Iteration: 5, Current Total Reward: -10000.0, Running Total Reward: -9490.87
# Iteration: 6, Current Total Reward: -4419.0, Running Total Reward: -8983.68
# Iteration: 7, Current Total Reward: -10000.0, Running Total Reward: -9085.31
# Iteration: 8, Current Total Reward: -10000.0, Running Total Reward: -9176.78
# Iteration: 9, Current Total Reward: -10000.0, Running Total Reward: -9259.1
# Iteration: 10, Current Total Reward: -1835.0, Running Total Reward: -8516.69
# Iteration: 11, Current Total Reward: -3741.0, Running Total Reward: -8039.12
# Iteration: 12, Current Total Reward: -6957.0, Running Total Reward: -7930.91
# Iteration: 13, Current Total Reward: -1640.0, Running Total Reward: -7301.82
# Iteration: 14, Current Total Reward: -1436.0, Running Total Reward: -6715.24
# Iteration: 15, Current Total Reward: -2351.0, Running Total Reward: -6278.82
# Iteration: 16, Current Total Reward: -3636.0, Running Total Reward: -6014.53
# Iteration: 17, Current Total Reward: -4072.0, Running Total Reward: -5820.28
# Iteration: 18, Current Total Reward: -3802.0, Running Total Reward: -5618.45
# Iteration: 19, Current Total Reward: -3482.0, Running Total Reward: -5404.81
# Iteration: 20, Current Total Reward: -3262.0, Running Total Reward: -5190.53
# Iteration: 21, Current Total Reward: -2558.0, Running Total Reward: -4927.27
# Iteration: 22, Current Total Reward: -1884.0, Running Total Reward: -4622.95
# Iteration: 23, Current Total Reward: -2580.0, Running Total Reward: -4418.65
# Iteration: 24, Current Total Reward: -2242.0, Running Total Reward: -4200.99
# Iteration: 25, Current Total Reward: -2717.0, Running Total Reward: -4052.59
# Iteration: 26, Current Total Reward: -2940.0, Running Total Reward: -3941.33
# Iteration: 27, Current Total Reward: -2192.0, Running Total Reward: -3766.4
# Iteration: 28, Current Total Reward: -3745.0, Running Total Reward: -3764.26
# Iteration: 29, Current Total Reward: -3272.0, Running Total Reward: -3715.03
# Iteration: 30, Current Total Reward: -2641.0, Running Total Reward: -3607.63
# Iteration: 31, Current Total Reward: -2759.0, Running Total Reward: -3522.77
# Iteration: 32, Current Total Reward: -2542.0, Running Total Reward: -3424.69
# Iteration: 33, Current Total Reward: -3623.0, Running Total Reward: -3444.52
# Iteration: 34, Current Total Reward: -2868.0, Running Total Reward: -3386.87
# Iteration: 35, Current Total Reward: -1606.0, Running Total Reward: -3208.78
# Iteration: 36, Current Total Reward: -4702.0, Running Total Reward: -3358.1
# Iteration: 37, Current Total Reward: -2651.0, Running Total Reward: -3287.39
# Iteration: 38, Current Total Reward: -4982.0, Running Total Reward: -3456.85
# Iteration: 39, Current Total Reward: -2877.0, Running Total Reward: -3398.87
# Iteration: 40, Current Total Reward: -2259.0, Running Total Reward: -3284.88
# Iteration: 41, Current Total Reward: -2590.0, Running Total Reward: -3215.39
# Iteration: 42, Current Total Reward: -1766.0, Running Total Reward: -3070.45
# Iteration: 43, Current Total Reward: -2884.0, Running Total Reward: -3051.81
# Iteration: 44, Current Total Reward: -2800.0, Running Total Reward: -3026.63
# Iteration: 45, Current Total Reward: -1177.0, Running Total Reward: -2841.66
# Iteration: 46, Current Total Reward: -2626.0, Running Total Reward: -2820.1
# Iteration: 47, Current Total Reward: -2716.0, Running Total Reward: -2809.69
# Iteration: 48, Current Total Reward: -3048.0, Running Total Reward: -2833.52
# Iteration: 49, Current Total Reward: -3097.0, Running Total Reward: -2859.87
# Iteration: 50, Current Total Reward: -3516.0, Running Total Reward: -2925.48
# Iteration: 51, Current Total Reward: -1579.0, Running Total Reward: -2790.83
# Iteration: 52, Current Total Reward: -4816.0, Running Total Reward: -2993.35
# Iteration: 53, Current Total Reward: -3416.0, Running Total Reward: -3035.61
# Iteration: 54, Current Total Reward: -8723.0, Running Total Reward: -3604.35
# Iteration: 55, Current Total Reward: -1812.0, Running Total Reward: -3425.12
# Iteration: 56, Current Total Reward: -4650.0, Running Total Reward: -3547.61
# Iteration: 57, Current Total Reward: -5355.0, Running Total Reward: -3728.35
# Iteration: 58, Current Total Reward: -1774.0, Running Total Reward: -3532.91
# Iteration: 59, Current Total Reward: -1948.0, Running Total Reward: -3374.42
# Iteration: 60, Current Total Reward: -3857.0, Running Total Reward: -3422.68
# Iteration: 61, Current Total Reward: -1633.0, Running Total Reward: -3243.71
# Iteration: 62, Current Total Reward: -2342.0, Running Total Reward: -3153.54
# Iteration: 63, Current Total Reward: -1346.0, Running Total Reward: -2972.79
# Iteration: 64, Current Total Reward: -2527.0, Running Total Reward: -2928.21
# Iteration: 65, Current Total Reward: -1813.0, Running Total Reward: -2816.69
# Iteration: 66, Current Total Reward: -2094.0, Running Total Reward: -2744.42
# Iteration: 67, Current Total Reward: -1335.0, Running Total Reward: -2603.48
# Iteration: 68, Current Total Reward: -4953.0, Running Total Reward: -2838.43
# Iteration: 69, Current Total Reward: -2571.0, Running Total Reward: -2811.69
# Iteration: 70, Current Total Reward: -2326.0, Running Total Reward: -2763.12
# Iteration: 71, Current Total Reward: -2215.0, Running Total Reward: -2708.31
# Iteration: 72, Current Total Reward: -4628.0, Running Total Reward: -2900.27
# Iteration: 73, Current Total Reward: -2250.0, Running Total Reward: -2835.25
# Iteration: 74, Current Total Reward: -2743.0, Running Total Reward: -2826.02
# Iteration: 75, Current Total Reward: -4134.0, Running Total Reward: -2956.82
# Iteration: 76, Current Total Reward: -1865.0, Running Total Reward: -2847.64
# Iteration: 77, Current Total Reward: -2655.0, Running Total Reward: -2828.37
# Iteration: 78, Current Total Reward: -4378.0, Running Total Reward: -2983.34
# Iteration: 79, Current Total Reward: -1447.0, Running Total Reward: -2829.7
# Iteration: 80, Current Total Reward: -2330.0, Running Total Reward: -2779.73
# Iteration: 81, Current Total Reward: -7109.0, Running Total Reward: -3212.66
# Iteration: 82, Current Total Reward: -3149.0, Running Total Reward: -3206.29
# Iteration: 83, Current Total Reward: -2375.0, Running Total Reward: -3123.16
# Iteration: 84, Current Total Reward: -4545.0, Running Total Reward: -3265.35
# Iteration: 85, Current Total Reward: -3737.0, Running Total Reward: -3312.51
# Iteration: 86, Current Total Reward: -2931.0, Running Total Reward: -3274.36
# Iteration: 87, Current Total Reward: -2224.0, Running Total Reward: -3169.33
# Iteration: 88, Current Total Reward: -5015.0, Running Total Reward: -3353.89
# Iteration: 89, Current Total Reward: -3866.0, Running Total Reward: -3405.1
# Iteration: 90, Current Total Reward: -2926.0, Running Total Reward: -3357.19
# Iteration: 91, Current Total Reward: -6965.0, Running Total Reward: -3717.97
# Iteration: 92, Current Total Reward: -2258.0, Running Total Reward: -3571.98
# Iteration: 93, Current Total Reward: -4669.0, Running Total Reward: -3681.68
# Iteration: 94, Current Total Reward: -1987.0, Running Total Reward: -3512.21
# Iteration: 95, Current Total Reward: -1644.0, Running Total Reward: -3325.39
# Iteration: 96, Current Total Reward: -3007.0, Running Total Reward: -3293.55
# Iteration: 97, Current Total Reward: -1588.0, Running Total Reward: -3123.0
# Iteration: 98, Current Total Reward: -6403.0, Running Total Reward: -3451.0
# Iteration: 99, Current Total Reward: -2468.0, Running Total Reward: -3352.7
# Iteration: 100, Current Total Reward: -1344.0, Running Total Reward: -3151.83
# Iteration: 101, Current Total Reward: -3412.0, Running Total Reward: -3177.84
# Iteration: 102, Current Total Reward: -3655.0, Running Total Reward: -3225.56
# Iteration: 103, Current Total Reward: -1340.0, Running Total Reward: -3037.0
# Iteration: 104, Current Total Reward: -3587.0, Running Total Reward: -3092.0
# Iteration: 105, Current Total Reward: -1519.0, Running Total Reward: -2934.7
# Iteration: 106, Current Total Reward: -4926.0, Running Total Reward: -3133.83
# Iteration: 107, Current Total Reward: -3542.0, Running Total Reward: -3174.65
# Iteration: 108, Current Total Reward: -2332.0, Running Total Reward: -3090.38
# Iteration: 109, Current Total Reward: -1756.0, Running Total Reward: -2956.95
# Iteration: 110, Current Total Reward: -1871.0, Running Total Reward: -2848.35
# Iteration: 111, Current Total Reward: -4405.0, Running Total Reward: -3004.02
# Iteration: 112, Current Total Reward: -1432.0, Running Total Reward: -2846.81
# Iteration: 113, Current Total Reward: -2338.0, Running Total Reward: -2795.93
# Iteration: 114, Current Total Reward: -4884.0, Running Total Reward: -3004.74
# Iteration: 115, Current Total Reward: -4062.0, Running Total Reward: -3110.47
# Iteration: 116, Current Total Reward: -8776.0, Running Total Reward: -3677.02
# Iteration: 117, Current Total Reward: -4841.0, Running Total Reward: -3793.42
# Iteration: 118, Current Total Reward: -4614.0, Running Total Reward: -3875.48
# Iteration: 119, Current Total Reward: -1973.0, Running Total Reward: -3685.23
# Iteration: 120, Current Total Reward: -4442.0, Running Total Reward: -3760.91
# Iteration: 121, Current Total Reward: -1631.0, Running Total Reward: -3547.91
# Iteration: 122, Current Total Reward: -2218.0, Running Total Reward: -3414.92
# Iteration: 123, Current Total Reward: -1746.0, Running Total Reward: -3248.03
# Iteration: 124, Current Total Reward: -1125.0, Running Total Reward: -3035.73
# Iteration: 125, Current Total Reward: -4359.0, Running Total Reward: -3168.06
# Iteration: 126, Current Total Reward: -2832.0, Running Total Reward: -3134.45
# Iteration: 127, Current Total Reward: -1908.0, Running Total Reward: -3011.8
# Iteration: 128, Current Total Reward: -1564.0, Running Total Reward: -2867.02
# Iteration: 129, Current Total Reward: -4742.0, Running Total Reward: -3054.52
# Iteration: 130, Current Total Reward: -3310.0, Running Total Reward: -3080.07
# Iteration: 131, Current Total Reward: -2597.0, Running Total Reward: -3031.76
# Iteration: 132, Current Total Reward: -1807.0, Running Total Reward: -2909.29
# Iteration: 133, Current Total Reward: -1911.0, Running Total Reward: -2809.46
# Iteration: 134, Current Total Reward: -3493.0, Running Total Reward: -2877.81
# Iteration: 135, Current Total Reward: -5107.0, Running Total Reward: -3100.73
# Iteration: 136, Current Total Reward: -2930.0, Running Total Reward: -3083.66
# Iteration: 137, Current Total Reward: -3487.0, Running Total Reward: -3123.99
# Iteration: 138, Current Total Reward: -4388.0, Running Total Reward: -3250.39
# Iteration: 139, Current Total Reward: -2857.0, Running Total Reward: -3211.05
# Iteration: 140, Current Total Reward: -4755.0, Running Total Reward: -3365.45
# Iteration: 141, Current Total Reward: -2154.0, Running Total Reward: -3244.3
# Iteration: 142, Current Total Reward: -2024.0, Running Total Reward: -3122.27
# Iteration: 143, Current Total Reward: -2516.0, Running Total Reward: -3061.65
# Iteration: 144, Current Total Reward: -2991.0, Running Total Reward: -3054.58
# Iteration: 145, Current Total Reward: -2866.0, Running Total Reward: -3035.72
# Iteration: 146, Current Total Reward: -3744.0, Running Total Reward: -3106.55
# Iteration: 147, Current Total Reward: -2458.0, Running Total Reward: -3041.7
# Iteration: 148, Current Total Reward: -2140.0, Running Total Reward: -2951.53
# Iteration: 149, Current Total Reward: -4332.0, Running Total Reward: -3089.57
# Iteration: 150, Current Total Reward: -3481.0, Running Total Reward: -3128.72
# Iteration: 151, Current Total Reward: -4000.0, Running Total Reward: -3215.84
# Iteration: 152, Current Total Reward: -1862.0, Running Total Reward: -3080.46
# Iteration: 153, Current Total Reward: -1510.0, Running Total Reward: -2923.41
# Iteration: 154, Current Total Reward: -3584.0, Running Total Reward: -2989.47
# Iteration: 155, Current Total Reward: -2173.0, Running Total Reward: -2907.83
# Iteration: 156, Current Total Reward: -3459.0, Running Total Reward: -2962.94
# Iteration: 157, Current Total Reward: -7010.0, Running Total Reward: -3367.65
# Iteration: 158, Current Total Reward: -1486.0, Running Total Reward: -3179.48
# Iteration: 159, Current Total Reward: -2091.0, Running Total Reward: -3070.64
# Iteration: 160, Current Total Reward: -3644.0, Running Total Reward: -3127.97
# Iteration: 161, Current Total Reward: -3512.0, Running Total Reward: -3166.37
# Iteration: 162, Current Total Reward: -3025.0, Running Total Reward: -3152.24
# Iteration: 163, Current Total Reward: -1324.0, Running Total Reward: -2969.41
# Iteration: 164, Current Total Reward: -2069.0, Running Total Reward: -2879.37
# Iteration: 165, Current Total Reward: -2449.0, Running Total Reward: -2836.33
# Iteration: 166, Current Total Reward: -4783.0, Running Total Reward: -3031.0
# Iteration: 167, Current Total Reward: -1593.0, Running Total Reward: -2887.2
# Iteration: 168, Current Total Reward: -2340.0, Running Total Reward: -2832.48
# Iteration: 169, Current Total Reward: -2205.0, Running Total Reward: -2769.73
# Iteration: 170, Current Total Reward: -2568.0, Running Total Reward: -2749.56
# Iteration: 171, Current Total Reward: -2600.0, Running Total Reward: -2734.6
# Iteration: 172, Current Total Reward: -5316.0, Running Total Reward: -2992.74
# Iteration: 173, Current Total Reward: -2838.0, Running Total Reward: -2977.27
# Iteration: 174, Current Total Reward: -6763.0, Running Total Reward: -3355.84
# Iteration: 175, Current Total Reward: -1946.0, Running Total Reward: -3214.86
# Iteration: 176, Current Total Reward: -4123.0, Running Total Reward: -3305.67
# Iteration: 177, Current Total Reward: -5948.0, Running Total Reward: -3569.9
# Iteration: 178, Current Total Reward: -2212.0, Running Total Reward: -3434.11
# Iteration: 179, Current Total Reward: -2245.0, Running Total Reward: -3315.2
# Iteration: 180, Current Total Reward: -2805.0, Running Total Reward: -3264.18
# Iteration: 181, Current Total Reward: -3424.0, Running Total Reward: -3280.16
# Iteration: 182, Current Total Reward: -4120.0, Running Total Reward: -3364.15
# Iteration: 183, Current Total Reward: -1672.0, Running Total Reward: -3194.93
# Iteration: 184, Current Total Reward: -2556.0, Running Total Reward: -3131.04
# Iteration: 185, Current Total Reward: -4364.0, Running Total Reward: -3254.34
# Iteration: 186, Current Total Reward: -2243.0, Running Total Reward: -3153.2
# Iteration: 187, Current Total Reward: -1371.0, Running Total Reward: -2974.98
# Iteration: 188, Current Total Reward: -2452.0, Running Total Reward: -2922.68
# Iteration: 189, Current Total Reward: -2775.0, Running Total Reward: -2907.92
# Iteration: 190, Current Total Reward: -2405.0, Running Total Reward: -2857.62
# Iteration: 191, Current Total Reward: -4481.0, Running Total Reward: -3019.96
# Iteration: 192, Current Total Reward: -3648.0, Running Total Reward: -3082.77
# Iteration: 193, Current Total Reward: -3302.0, Running Total Reward: -3104.69
# Iteration: 194, Current Total Reward: -2650.0, Running Total Reward: -3059.22
# Iteration: 195, Current Total Reward: -1893.0, Running Total Reward: -2942.6
# Iteration: 196, Current Total Reward: -1719.0, Running Total Reward: -2820.24
# Iteration: 197, Current Total Reward: -1877.0, Running Total Reward: -2725.91
# Iteration: 198, Current Total Reward: -3693.0, Running Total Reward: -2822.62
# Iteration: 199, Current Total Reward: -2403.0, Running Total Reward: -2780.66
# Iteration: 200, Current Total Reward: -3248.0, Running Total Reward: -2827.39
# Iteration: 201, Current Total Reward: -1844.0, Running Total Reward: -2729.06
# Iteration: 202, Current Total Reward: -2667.0, Running Total Reward: -2722.85
# Iteration: 203, Current Total Reward: -5630.0, Running Total Reward: -3013.56
# Iteration: 204, Current Total Reward: -1708.0, Running Total Reward: -2883.01
# Iteration: 205, Current Total Reward: -2883.0, Running Total Reward: -2883.01
# Iteration: 206, Current Total Reward: -2910.0, Running Total Reward: -2885.71
# Iteration: 207, Current Total Reward: -1661.0, Running Total Reward: -2763.24
# Iteration: 208, Current Total Reward: -2674.0, Running Total Reward: -2754.31
# Iteration: 209, Current Total Reward: -3852.0, Running Total Reward: -2864.08
# Iteration: 210, Current Total Reward: -4043.0, Running Total Reward: -2981.97
# Iteration: 211, Current Total Reward: -6181.0, Running Total Reward: -3301.88
# Iteration: 212, Current Total Reward: -1604.0, Running Total Reward: -3132.09
# Iteration: 213, Current Total Reward: -2452.0, Running Total Reward: -3064.08
# Iteration: 214, Current Total Reward: -2572.0, Running Total Reward: -3014.87
# Iteration: 215, Current Total Reward: -3089.0, Running Total Reward: -3022.28
# Iteration: 216, Current Total Reward: -1600.0, Running Total Reward: -2880.06
# Iteration: 217, Current Total Reward: -5243.0, Running Total Reward: -3116.35
# Iteration: 218, Current Total Reward: -3812.0, Running Total Reward: -3185.92
# Iteration: 219, Current Total Reward: -2150.0, Running Total Reward: -3082.32
# Iteration: 220, Current Total Reward: -1817.0, Running Total Reward: -2955.79
# Iteration: 221, Current Total Reward: -1331.0, Running Total Reward: -2793.31
# Iteration: 222, Current Total Reward: -3248.0, Running Total Reward: -2838.78
# Iteration: 223, Current Total Reward: -2424.0, Running Total Reward: -2797.3
# Iteration: 224, Current Total Reward: -2156.0, Running Total Reward: -2733.17
# Iteration: 225, Current Total Reward: -3818.0, Running Total Reward: -2841.66
# Iteration: 226, Current Total Reward: -2327.0, Running Total Reward: -2790.19
# Iteration: 227, Current Total Reward: -3307.0, Running Total Reward: -2841.87
# Iteration: 228, Current Total Reward: -1509.0, Running Total Reward: -2708.58
# Iteration: 229, Current Total Reward: -2071.0, Running Total Reward: -2644.83
# Iteration: 230, Current Total Reward: -4443.0, Running Total Reward: -2824.64
# Iteration: 231, Current Total Reward: -2850.0, Running Total Reward: -2827.18
# Iteration: 232, Current Total Reward: -3596.0, Running Total Reward: -2904.06
# Iteration: 233, Current Total Reward: -2491.0, Running Total Reward: -2862.75
# Iteration: 234, Current Total Reward: -1369.0, Running Total Reward: -2713.38
# Iteration: 235, Current Total Reward: -4385.0, Running Total Reward: -2880.54
# Iteration: 236, Current Total Reward: -3272.0, Running Total Reward: -2919.69
# Iteration: 237, Current Total Reward: -3539.0, Running Total Reward: -2981.62
# Iteration: 238, Current Total Reward: -3438.0, Running Total Reward: -3027.26
# Iteration: 239, Current Total Reward: -1506.0, Running Total Reward: -2875.13
# Iteration: 240, Current Total Reward: -2345.0, Running Total Reward: -2822.12
# Iteration: 241, Current Total Reward: -4977.0, Running Total Reward: -3037.61
# Iteration: 242, Current Total Reward: -3550.0, Running Total Reward: -3088.85
# Iteration: 243, Current Total Reward: -1362.0, Running Total Reward: -2916.16
# Iteration: 244, Current Total Reward: -2939.0, Running Total Reward: -2918.44
# Iteration: 245, Current Total Reward: -5906.0, Running Total Reward: -3217.2
# Iteration: 246, Current Total Reward: -3424.0, Running Total Reward: -3237.88
# Iteration: 247, Current Total Reward: -2101.0, Running Total Reward: -3124.19
# Iteration: 248, Current Total Reward: -5654.0, Running Total Reward: -3377.17
# Iteration: 249, Current Total Reward: -1186.0, Running Total Reward: -3158.06
# Iteration: 250, Current Total Reward: -4049.0, Running Total Reward: -3247.15
# Iteration: 251, Current Total Reward: -3005.0, Running Total Reward: -3222.94
# Iteration: 252, Current Total Reward: -3604.0, Running Total Reward: -3261.04
# Iteration: 253, Current Total Reward: -2709.0, Running Total Reward: -3205.84
# Iteration: 254, Current Total Reward: -4675.0, Running Total Reward: -3352.75
# Iteration: 255, Current Total Reward: -2469.0, Running Total Reward: -3264.38
# Iteration: 256, Current Total Reward: -1959.0, Running Total Reward: -3133.84
# Iteration: 257, Current Total Reward: -6154.0, Running Total Reward: -3435.86
# Iteration: 258, Current Total Reward: -1695.0, Running Total Reward: -3261.77
# Iteration: 259, Current Total Reward: -1512.0, Running Total Reward: -3086.79
# Iteration: 260, Current Total Reward: -5582.0, Running Total Reward: -3336.31
# Iteration: 261, Current Total Reward: -2436.0, Running Total Reward: -3246.28
# Iteration: 262, Current Total Reward: -3790.0, Running Total Reward: -3300.65
# Iteration: 263, Current Total Reward: -4194.0, Running Total Reward: -3389.99
# Iteration: 264, Current Total Reward: -3116.0, Running Total Reward: -3362.59
# Iteration: 265, Current Total Reward: -1335.0, Running Total Reward: -3159.83
# Iteration: 266, Current Total Reward: -1528.0, Running Total Reward: -2996.65
# Iteration: 267, Current Total Reward: -3553.0, Running Total Reward: -3052.28
# Iteration: 268, Current Total Reward: -3401.0, Running Total Reward: -3087.15
# Iteration: 269, Current Total Reward: -1424.0, Running Total Reward: -2920.84
# Iteration: 270, Current Total Reward: -973.0, Running Total Reward: -2726.06
# Iteration: 271, Current Total Reward: -2611.0, Running Total Reward: -2714.55
# Iteration: 272, Current Total Reward: -4702.0, Running Total Reward: -2913.29
# Iteration: 273, Current Total Reward: -1761.0, Running Total Reward: -2798.07
# Iteration: 274, Current Total Reward: -2974.0, Running Total Reward: -2815.66
# Iteration: 275, Current Total Reward: -3527.0, Running Total Reward: -2886.79
# Iteration: 276, Current Total Reward: -5157.0, Running Total Reward: -3113.81
# Iteration: 277, Current Total Reward: -1840.0, Running Total Reward: -2986.43
# Iteration: 278, Current Total Reward: -4046.0, Running Total Reward: -3092.39
# Iteration: 279, Current Total Reward: -4132.0, Running Total Reward: -3196.35
# Iteration: 280, Current Total Reward: -3566.0, Running Total Reward: -3233.32
# Iteration: 281, Current Total Reward: -1414.0, Running Total Reward: -3051.38
# Iteration: 282, Current Total Reward: -3710.0, Running Total Reward: -3117.25
# Iteration: 283, Current Total Reward: -1815.0, Running Total Reward: -2987.02
# Iteration: 284, Current Total Reward: -2408.0, Running Total Reward: -2929.12
# Iteration: 285, Current Total Reward: -3346.0, Running Total Reward: -2970.81
# Iteration: 286, Current Total Reward: -2861.0, Running Total Reward: -2959.83
# Iteration: 287, Current Total Reward: -1841.0, Running Total Reward: -2847.94
# Iteration: 288, Current Total Reward: -1867.0, Running Total Reward: -2749.85
# Iteration: 289, Current Total Reward: -3397.0, Running Total Reward: -2814.56
# Iteration: 290, Current Total Reward: -2208.0, Running Total Reward: -2753.91
# Iteration: 291, Current Total Reward: -2960.0, Running Total Reward: -2774.52
# Iteration: 292, Current Total Reward: -2375.0, Running Total Reward: -2734.57
# Iteration: 293, Current Total Reward: -3567.0, Running Total Reward: -2817.81
# Iteration: 294, Current Total Reward: -1829.0, Running Total Reward: -2718.93
# Iteration: 295, Current Total Reward: -3096.0, Running Total Reward: -2756.64
# Iteration: 296, Current Total Reward: -1826.0, Running Total Reward: -2663.57
# Iteration: 297, Current Total Reward: -1825.0, Running Total Reward: -2579.71
# Iteration: 298, Current Total Reward: -2066.0, Running Total Reward: -2528.34
# Iteration: 299, Current Total Reward: -4712.0, Running Total Reward: -2746.71
# Iteration: 300, Current Total Reward: -9185.0, Running Total Reward: -3390.54
# Iteration: 301, Current Total Reward: -2413.0, Running Total Reward: -3292.78
# Iteration: 302, Current Total Reward: -2272.0, Running Total Reward: -3190.71
# Iteration: 303, Current Total Reward: -1868.0, Running Total Reward: -3058.44
# Iteration: 304, Current Total Reward: -1651.0, Running Total Reward: -2917.69
# Iteration: 305, Current Total Reward: -1866.0, Running Total Reward: -2812.52
# Iteration: 306, Current Total Reward: -2360.0, Running Total Reward: -2767.27
# Iteration: 307, Current Total Reward: -2030.0, Running Total Reward: -2693.54
# Iteration: 308, Current Total Reward: -1179.0, Running Total Reward: -2542.09
# Iteration: 309, Current Total Reward: -3196.0, Running Total Reward: -2607.48
# Iteration: 310, Current Total Reward: -2470.0, Running Total Reward: -2593.73
# Iteration: 311, Current Total Reward: -2813.0, Running Total Reward: -2615.66
# Iteration: 312, Current Total Reward: -2458.0, Running Total Reward: -2599.89
# Iteration: 313, Current Total Reward: -5197.0, Running Total Reward: -2859.6
# Iteration: 314, Current Total Reward: -2889.0, Running Total Reward: -2862.54
# Iteration: 315, Current Total Reward: -5422.0, Running Total Reward: -3118.49
# Iteration: 316, Current Total Reward: -1807.0, Running Total Reward: -2987.34
# Iteration: 317, Current Total Reward: -3720.0, Running Total Reward: -3060.61
# Iteration: 318, Current Total Reward: -2048.0, Running Total Reward: -2959.35
# Iteration: 319, Current Total Reward: -2400.0, Running Total Reward: -2903.41
# Iteration: 320, Current Total Reward: -1369.0, Running Total Reward: -2749.97
# Iteration: 321, Current Total Reward: -1452.0, Running Total Reward: -2620.17
# Iteration: 322, Current Total Reward: -5172.0, Running Total Reward: -2875.36
# Iteration: 323, Current Total Reward: -2530.0, Running Total Reward: -2840.82
# Iteration: 324, Current Total Reward: -1691.0, Running Total Reward: -2725.84
# Iteration: 325, Current Total Reward: -2478.0, Running Total Reward: -2701.05
# Iteration: 326, Current Total Reward: -2030.0, Running Total Reward: -2633.95
# Iteration: 327, Current Total Reward: -2292.0, Running Total Reward: -2599.75
# Iteration: 328, Current Total Reward: -3353.0, Running Total Reward: -2675.08
# Iteration: 329, Current Total Reward: -5784.0, Running Total Reward: -2985.97
# Iteration: 330, Current Total Reward: -2656.0, Running Total Reward: -2952.97
# Iteration: 331, Current Total Reward: -4060.0, Running Total Reward: -3063.68
# Iteration: 332, Current Total Reward: -2251.0, Running Total Reward: -2982.41
# Iteration: 333, Current Total Reward: -1809.0, Running Total Reward: -2865.07
# Iteration: 334, Current Total Reward: -2670.0, Running Total Reward: -2845.56
# Iteration: 335, Current Total Reward: -2001.0, Running Total Reward: -2761.1
# Iteration: 336, Current Total Reward: -1660.0, Running Total Reward: -2650.99
# Iteration: 337, Current Total Reward: -3955.0, Running Total Reward: -2781.39
# Iteration: 338, Current Total Reward: -1772.0, Running Total Reward: -2680.46
# Iteration: 339, Current Total Reward: -3292.0, Running Total Reward: -2741.61
# Iteration: 340, Current Total Reward: -5802.0, Running Total Reward: -3047.65
# Iteration: 341, Current Total Reward: -6014.0, Running Total Reward: -3344.28
# Iteration: 342, Current Total Reward: -1801.0, Running Total Reward: -3189.96
# Iteration: 343, Current Total Reward: -1731.0, Running Total Reward: -3044.06
# Iteration: 344, Current Total Reward: -2030.0, Running Total Reward: -2942.65
# Iteration: 345, Current Total Reward: -1855.0, Running Total Reward: -2833.89
# Iteration: 346, Current Total Reward: -2371.0, Running Total Reward: -2787.6
# Iteration: 347, Current Total Reward: -2048.0, Running Total Reward: -2713.64
# Iteration: 348, Current Total Reward: -2759.0, Running Total Reward: -2718.18
# Iteration: 349, Current Total Reward: -1425.0, Running Total Reward: -2588.86
# Iteration: 350, Current Total Reward: -6405.0, Running Total Reward: -2970.47
# Iteration: 351, Current Total Reward: -1919.0, Running Total Reward: -2865.33
# Iteration: 352, Current Total Reward: -1317.0, Running Total Reward: -2710.49
# Iteration: 353, Current Total Reward: -3819.0, Running Total Reward: -2821.34
# Iteration: 354, Current Total Reward: -2458.0, Running Total Reward: -2785.01
# Iteration: 355, Current Total Reward: -974.0, Running Total Reward: -2603.91
# Iteration: 356, Current Total Reward: -3463.0, Running Total Reward: -2689.82
# Iteration: 357, Current Total Reward: -4267.0, Running Total Reward: -2847.54
# Iteration: 358, Current Total Reward: -3884.0, Running Total Reward: -2951.18
# Iteration: 359, Current Total Reward: -2137.0, Running Total Reward: -2869.76
# Iteration: 360, Current Total Reward: -1939.0, Running Total Reward: -2776.69
# Iteration: 361, Current Total Reward: -3083.0, Running Total Reward: -2807.32
# Iteration: 362, Current Total Reward: -1455.0, Running Total Reward: -2672.09
# Iteration: 363, Current Total Reward: -2638.0, Running Total Reward: -2668.68
# Iteration: 364, Current Total Reward: -2060.0, Running Total Reward: -2607.81
# Iteration: 365, Current Total Reward: -2316.0, Running Total Reward: -2578.63
# Iteration: 366, Current Total Reward: -1384.0, Running Total Reward: -2459.17
# Iteration: 367, Current Total Reward: -3949.0, Running Total Reward: -2608.15
# Iteration: 368, Current Total Reward: -5350.0, Running Total Reward: -2882.33
# Iteration: 369, Current Total Reward: -1300.0, Running Total Reward: -2724.1
# Iteration: 370, Current Total Reward: -2456.0, Running Total Reward: -2697.29
# Iteration: 371, Current Total Reward: -4002.0, Running Total Reward: -2827.76
# Iteration: 372, Current Total Reward: -3310.0, Running Total Reward: -2875.99
# Iteration: 373, Current Total Reward: -1136.0, Running Total Reward: -2701.99
# Iteration: 374, Current Total Reward: -2662.0, Running Total Reward: -2697.99
# Iteration: 375, Current Total Reward: -1984.0, Running Total Reward: -2626.59
# Iteration: 376, Current Total Reward: -3426.0, Running Total Reward: -2706.53
# Iteration: 377, Current Total Reward: -3595.0, Running Total Reward: -2795.38
# Iteration: 378, Current Total Reward: -2577.0, Running Total Reward: -2773.54
# Iteration: 379, Current Total Reward: -2185.0, Running Total Reward: -2714.69
# Iteration: 380, Current Total Reward: -3168.0, Running Total Reward: -2760.02
# Iteration: 381, Current Total Reward: -2166.0, Running Total Reward: -2700.62
# Iteration: 382, Current Total Reward: -3612.0, Running Total Reward: -2791.75
# Iteration: 383, Current Total Reward: -3163.0, Running Total Reward: -2828.88
# Iteration: 384, Current Total Reward: -2171.0, Running Total Reward: -2763.09
# Iteration: 385, Current Total Reward: -1939.0, Running Total Reward: -2680.68
# Iteration: 386, Current Total Reward: -1445.0, Running Total Reward: -2557.11
# Iteration: 387, Current Total Reward: -2530.0, Running Total Reward: -2554.4
# Iteration: 388, Current Total Reward: -3091.0, Running Total Reward: -2608.06
# Iteration: 389, Current Total Reward: -3601.0, Running Total Reward: -2707.36
# Iteration: 390, Current Total Reward: -2230.0, Running Total Reward: -2659.62
# Iteration: 391, Current Total Reward: -1715.0, Running Total Reward: -2565.16
# Iteration: 392, Current Total Reward: -1456.0, Running Total Reward: -2454.24
# Iteration: 393, Current Total Reward: -2371.0, Running Total Reward: -2445.92
# Iteration: 394, Current Total Reward: -2706.0, Running Total Reward: -2471.93
# Iteration: 395, Current Total Reward: -4325.0, Running Total Reward: -2657.23
# Iteration: 396, Current Total Reward: -2220.0, Running Total Reward: -2613.51
# Iteration: 397, Current Total Reward: -2619.0, Running Total Reward: -2614.06
# Iteration: 398, Current Total Reward: -1767.0, Running Total Reward: -2529.35
# Iteration: 399, Current Total Reward: -2478.0, Running Total Reward: -2524.22
# Iteration: 400, Current Total Reward: -3492.0, Running Total Reward: -2621.0
# Iteration: 401, Current Total Reward: -2512.0, Running Total Reward: -2610.1
# Iteration: 402, Current Total Reward: -1824.0, Running Total Reward: -2531.49
# Iteration: 403, Current Total Reward: -1085.0, Running Total Reward: -2386.84
# Iteration: 404, Current Total Reward: -3889.0, Running Total Reward: -2537.05
# Iteration: 405, Current Total Reward: -2182.0, Running Total Reward: -2501.55
# Iteration: 406, Current Total Reward: -1075.0, Running Total Reward: -2358.89
# Iteration: 407, Current Total Reward: -1264.0, Running Total Reward: -2249.4
# Iteration: 408, Current Total Reward: -1912.0, Running Total Reward: -2215.66
# Iteration: 409, Current Total Reward: -3475.0, Running Total Reward: -2341.6
# Iteration: 410, Current Total Reward: -5221.0, Running Total Reward: -2629.54
# Iteration: 411, Current Total Reward: -1646.0, Running Total Reward: -2531.18
# Iteration: 412, Current Total Reward: -2959.0, Running Total Reward: -2573.97
# Iteration: 413, Current Total Reward: -2443.0, Running Total Reward: -2560.87
# Iteration: 414, Current Total Reward: -1320.0, Running Total Reward: -2436.78
# Iteration: 415, Current Total Reward: -3955.0, Running Total Reward: -2588.6
# Iteration: 416, Current Total Reward: -2317.0, Running Total Reward: -2561.44
# Iteration: 417, Current Total Reward: -4795.0, Running Total Reward: -2784.8
# Iteration: 418, Current Total Reward: -3496.0, Running Total Reward: -2855.92
# Iteration: 419, Current Total Reward: -4389.0, Running Total Reward: -3009.23
# Iteration: 420, Current Total Reward: -2090.0, Running Total Reward: -2917.3
# Iteration: 421, Current Total Reward: -4633.0, Running Total Reward: -3088.87
# Iteration: 422, Current Total Reward: -2212.0, Running Total Reward: -3001.19
# Iteration: 423, Current Total Reward: -3521.0, Running Total Reward: -3053.17
# Iteration: 424, Current Total Reward: -3050.0, Running Total Reward: -3052.85
# Iteration: 425, Current Total Reward: -2196.0, Running Total Reward: -2967.17
# Iteration: 426, Current Total Reward: -3130.0, Running Total Reward: -2983.45
# Iteration: 427, Current Total Reward: -2053.0, Running Total Reward: -2890.4
# Iteration: 428, Current Total Reward: -1186.0, Running Total Reward: -2719.96
# Iteration: 429, Current Total Reward: -1272.0, Running Total Reward: -2575.17
# Iteration: 430, Current Total Reward: -3940.0, Running Total Reward: -2711.65
# Iteration: 431, Current Total Reward: -2793.0, Running Total Reward: -2719.79
# Iteration: 432, Current Total Reward: -1548.0, Running Total Reward: -2602.61
# Iteration: 433, Current Total Reward: -1808.0, Running Total Reward: -2523.15
# Iteration: 434, Current Total Reward: -2046.0, Running Total Reward: -2475.43
# Iteration: 435, Current Total Reward: -762.0, Running Total Reward: -2304.09
# Iteration: 436, Current Total Reward: -1593.0, Running Total Reward: -2232.98
# Iteration: 437, Current Total Reward: -1368.0, Running Total Reward: -2146.48
# Iteration: 438, Current Total Reward: -2842.0, Running Total Reward: -2216.03
# Iteration: 439, Current Total Reward: -1765.0, Running Total Reward: -2170.93
# Iteration: 440, Current Total Reward: -2343.0, Running Total Reward: -2188.14
# Iteration: 441, Current Total Reward: -1480.0, Running Total Reward: -2117.32
# Iteration: 442, Current Total Reward: -4436.0, Running Total Reward: -2349.19
# Iteration: 443, Current Total Reward: -1118.0, Running Total Reward: -2226.07
# Iteration: 444, Current Total Reward: -3292.0, Running Total Reward: -2332.66
# Iteration: 445, Current Total Reward: -1954.0, Running Total Reward: -2294.8
# Iteration: 446, Current Total Reward: -5168.0, Running Total Reward: -2582.12
# Iteration: 447, Current Total Reward: -1625.0, Running Total Reward: -2486.41
# Iteration: 448, Current Total Reward: -1348.0, Running Total Reward: -2372.57
# Iteration: 449, Current Total Reward: -1609.0, Running Total Reward: -2296.21
# Iteration: 450, Current Total Reward: -3596.0, Running Total Reward: -2426.19
# Iteration: 451, Current Total Reward: -3177.0, Running Total Reward: -2501.27
# Iteration: 452, Current Total Reward: -2705.0, Running Total Reward: -2521.64
# Iteration: 453, Current Total Reward: -2779.0, Running Total Reward: -2547.38
# Iteration: 454, Current Total Reward: -4511.0, Running Total Reward: -2743.74
# Iteration: 455, Current Total Reward: -682.0, Running Total Reward: -2537.57
# Iteration: 456, Current Total Reward: -2348.0, Running Total Reward: -2518.61
# Iteration: 457, Current Total Reward: -2539.0, Running Total Reward: -2520.65
# Iteration: 458, Current Total Reward: -2281.0, Running Total Reward: -2496.68
# Iteration: 459, Current Total Reward: -3471.0, Running Total Reward: -2594.12
# Iteration: 460, Current Total Reward: -5465.0, Running Total Reward: -2881.2
# Iteration: 461, Current Total Reward: -2506.0, Running Total Reward: -2843.68
# Iteration: 462, Current Total Reward: -1874.0, Running Total Reward: -2746.72
# Iteration: 463, Current Total Reward: -2015.0, Running Total Reward: -2673.54
# Iteration: 464, Current Total Reward: -2406.0, Running Total Reward: -2646.79
# Iteration: 465, Current Total Reward: -2048.0, Running Total Reward: -2586.91
# Iteration: 466, Current Total Reward: -2814.0, Running Total Reward: -2609.62
# Iteration: 467, Current Total Reward: -4436.0, Running Total Reward: -2792.26
# Iteration: 468, Current Total Reward: -3372.0, Running Total Reward: -2850.23
# Iteration: 469, Current Total Reward: -1264.0, Running Total Reward: -2691.61
# Iteration: 470, Current Total Reward: -2302.0, Running Total Reward: -2652.65
# Iteration: 471, Current Total Reward: -4224.0, Running Total Reward: -2809.78
# Iteration: 472, Current Total Reward: -3019.0, Running Total Reward: -2830.7
# Iteration: 473, Current Total Reward: -1833.0, Running Total Reward: -2730.93
# Iteration: 474, Current Total Reward: -3061.0, Running Total Reward: -2763.94
# Iteration: 475, Current Total Reward: -3881.0, Running Total Reward: -2875.65
# Iteration: 476, Current Total Reward: -2468.0, Running Total Reward: -2834.88
# Iteration: 477, Current Total Reward: -3379.0, Running Total Reward: -2889.29
# Iteration: 478, Current Total Reward: -3321.0, Running Total Reward: -2932.46
# Iteration: 479, Current Total Reward: -1870.0, Running Total Reward: -2826.22
# Iteration: 480, Current Total Reward: -3253.0, Running Total Reward: -2868.9
# Iteration: 481, Current Total Reward: -2160.0, Running Total Reward: -2798.01
# Iteration: 482, Current Total Reward: -1699.0, Running Total Reward: -2688.11
# Iteration: 483, Current Total Reward: -2118.0, Running Total Reward: -2631.1
# Iteration: 484, Current Total Reward: -1786.0, Running Total Reward: -2546.59
# Iteration: 485, Current Total Reward: -6565.0, Running Total Reward: -2948.43
# Iteration: 486, Current Total Reward: -1821.0, Running Total Reward: -2835.68
# Iteration: 487, Current Total Reward: -2832.0, Running Total Reward: -2835.32
# Iteration: 488, Current Total Reward: -4435.0, Running Total Reward: -2995.28
# Iteration: 489, Current Total Reward: -2010.0, Running Total Reward: -2896.76
# Iteration: 490, Current Total Reward: -1357.0, Running Total Reward: -2742.78
# Iteration: 491, Current Total Reward: -4221.0, Running Total Reward: -2890.6
# Iteration: 492, Current Total Reward: -2764.0, Running Total Reward: -2877.94
# Iteration: 493, Current Total Reward: -842.0, Running Total Reward: -2674.35
# Iteration: 494, Current Total Reward: -1558.0, Running Total Reward: -2562.71
# Iteration: 495, Current Total Reward: -1402.0, Running Total Reward: -2446.64
# Iteration: 496, Current Total Reward: -1935.0, Running Total Reward: -2395.48
# Iteration: 497, Current Total Reward: -3096.0, Running Total Reward: -2465.53
# Iteration: 498, Current Total Reward: -1881.0, Running Total Reward: -2407.08
# Iteration: 499, Current Total Reward: -2118.0, Running Total Reward: -2378.17
